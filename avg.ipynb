# %% [markdown]
# ## main

# %%
import random
import numpy as np
import pandas as pd
import time 
from gurobipy import Model, GRB, quicksum

from stable_baselines3.common.noise import NormalActionNoise
import matplotlib.pyplot as plt
import seaborn as sns

from typing import Optional

import os
from functools import lru_cache
from collections import defaultdict
         

K = 25  #number of PRB
T = 10  #number of Slot
num_simulations = 500

    
# Apps SLA dictionaries in bits
SLA_critic = {1: 400, 2:900}   
SLA_perf   = {3: 10000, 4: 20}  
SLA_busi   = {5: 20000}        


# Application categories identifier
Ac = [1, 2]  # critical 1: ETCS  2: Voice 
Ap = [3, 4]  # performance  3: CCTV , 4: PID
Ab = [5]     # Business 5: Pwifi

U_c = 6 # number of critical UE
U_p = 5 # number of performance UE
U_b = 4 # number of business UE

# Application labels
app_labels = ['ETCS', 'Voice', 'CCTV', 'PIS', 'Pwifi']
sla_values = [
    SLA_critic.get(1, 0),
    SLA_critic.get(2, 0),
    SLA_perf.get(3, 0),
    SLA_perf.get(4, 0),
    SLA_busi.get(5, 0)
]

#Data Rate parameters

J = 1  # Number of component carriers
v_Llayers = 1  # Maximum number of MIMO layers

OH = 0.14  # Overhead (e.g., FR1 DL)
f = 1  # Scaling factor
mu = 0  # Numerology (0 for 15 kHz SCS)

# CQI to Modulation Order (Q_m)
CQI_TO_MCS = {
    1: 2, 2: 2, 3: 2, 4: 4, 5: 4,
    6: 4, 7: 4, 8: 6, 9: 6, 10: 6,
    11: 6, 12: 6, 13: 8, 14: 8, 15: 8
}

# CQI to Coding Rate (R_max)
CQI_TO_Rmax = {
    1: 0.07617188,  # QPSK
    2: 0.18847656,  # QPSK
    3: 0.43847656,  # QPSK
    4: 0.36914063,  # QPSK
    5: 0.47851563,  # QPSK
    6: 0.6015625,   # QPSK
    7: 0.45507813,  # 16-QAM
    8: 0.55371094,  # 16-QAM
    9: 0.65039063,  # 16-QAM
    10: 0.75390625, # 64-QAM
    11: 0.85253906, # 64-QAM
    12: 0.69433594, # 64-QAM
    13: 0.77832031, # 64-QAM
    14: 0.86425781, # 64-QAM
    15: 0.92578125, # 64-QAM
}

# OFDM symbol duration (T_s) based on numerology
T_s = 10**-3 / (14 * 2**mu)  

def calculate_minmum_required_datarate():
    # Sum required bits for critical, performance and business  apps 
    crit_req = U_c * (SLA_critic[1] + SLA_critic[2])
    
    perf_req = U_p * (SLA_perf[3] + SLA_perf[4])
    
    busi_req = U_b * SLA_busi[5]
    
    total_required_bits = crit_req + perf_req + busi_req
    total_required_bits = total_required_bits/1000 
    return total_required_bits
min_required_datarate_KB = calculate_minmum_required_datarate()
print(f"the minimumrequire {min_required_datarate_KB}")


# ------------------------------------------------------------
# generate_gamma(): using real sub-band-CQI measurements
# ------------------------------------------------------------

DATA_DIR = "subband_cqi"            # folder that holds TOBA gateway subband CQI : UE0.csv … UE<n>.csv


@lru_cache(maxsize=None)
def _load_ue_dataframe(ue_idx: int) -> pd.DataFrame:
    """Read (and cache) the CSV of one UE."""
    path = os.path.join(DATA_DIR, f"Subband_UE{ue_idx}.csv")
    if not os.path.isfile(path):
        raise FileNotFoundError(f"Missing CQI file: {path}")
    return pd.read_csv(path)

def _pick_row(df: pd.DataFrame, time_idx: Optional[int] = None) -> pd.Series:
    """Return one row of CQI values (RGB0…RGB6)."""
    if time_idx is None:                       # if no index specified choose a random instant
        return df.sample(n=1).iloc[0]
    else:                                      # else deterministic index specified
        return df.iloc[time_idx % len(df)]

def _rgb_for_prb(k_: int) -> int:
    """Map PRB index → RGB index (0-6)."""
    return k_ // 4 if k_ < 24 else 6

def generate_gamma(time_idx: Optional[int] = None):
    """
    Build the γ-dictionary using real CQI traces.
    these achievable data rate base on subband CQI
    Parameters
    ----------
    time_idx : int or None
        • None  → use a random row from each UE file (default)  
        • int   → deterministic: row `time_idx` 
    """
    gamma = {}

    def add_entries(local_i: int, global_i: int, slice_id: int, apps: list[int]):
        # --- pick one CQI row for this UE --------------------
        row = _pick_row(_load_ue_dataframe(global_i), time_idx)
        rgb_cqi = [int(row[f"RGB{g}"]) for g in range(7)]

        for a in apps:                        # same CQI for every app of that UE (=TOBA Garteway)
            for k_ in range(K):               # PRB ➜ RGB mapping
                cqi = rgb_cqi[_rgb_for_prb(k_)]
                R_max = CQI_TO_Rmax.get(cqi, 0)
                Q_m   = CQI_TO_MCS .get(cqi, 0)
                thr = (1e-3 * J * v_Llayers * Q_m * f * R_max * (12 / T_s) * (1 - OH))
                gamma[(global_i, a, slice_id, k_)] = thr   # **global_i here**

    # ── enter appplications into gamma based on specifie Number of user in Ac, Ab and Ac (Critic. Perf.Busi)
    for i in range(U_c):
        add_entries(i, i, 1, Ac)
    
    for i in range(U_p):
        add_entries(i, U_c + i, 2, Ap)

    for i in range(U_b):
        add_entries(i, U_c + U_p + i, 3, Ab)

    return gamma

#build list of applications
def build_appkey_list():
    appkey_list = []

    # Critical slice (UE 0-5)
    for i in range(U_c):
        for a in Ac:
            appkey_list.append((i, a, 1))

    # Performance slice (UE 6-10)
    for i in range(U_p):
        g = U_c + i
        for a in Ap:
            appkey_list.append((g, a, 2))

    # Business slice (UE 11-14)
    for i in range(U_b):
        g = U_c + U_p + i
        for a in Ab:
            appkey_list.append((g, a, 3))

    return appkey_list

APPKEY_LIST = build_appkey_list()
N_APPKEYS = len(APPKEY_LIST)

def get_sla(app):
    if app in SLA_critic:
        return SLA_critic[app]
    if app in SLA_perf:
        return SLA_perf[app]
    if app in SLA_busi:
        return SLA_busi[app]
    return 0

def get_slice_for_app(app_id):
    if app_id in Ac:
        return 1
    elif app_id in Ap:
        return 2
    else:
        return 3

def get_num_users_for_slice(slice_id):
    if slice_id == 1:
        return U_c
    elif slice_id == 2:
        return U_p
    elif slice_id == 3:
        return U_b

def run_allocation_solver(gamma, wc=0.01, wp=0.6, wb=1):
    """
    Optimal ILP (Gurobi) allocation 
    """

    # Sort TOBA gatexyas (UE)  ids per slices
    crit_users = sorted({i for (i, a, s, _) in gamma if s == 1})  
    perf_users = sorted({i for (i, a, s, _) in gamma if s == 2})  
    busi_users = sorted({i for (i, a, s, _) in gamma if s == 3})  

    U_c, U_p, U_b = len(crit_users), len(perf_users), len(busi_users)

    # ------------------------------------------------------------
    # 1)  Model & variables 
    # ------------------------------------------------------------
    model = Model("Optimal_ILP")
    model.Params.LogToConsole = 0
    model.setParam("NodefileStart", 0.010)
    model.setParam("NodefileDir", "/tmp")
    model.setParam("Threads", 16)
    model.setParam("MIPFocus", 1)
    model.setParam("ConcurrentMIP", 4)
    model.setParam("TimeLimit", 10) 

    x = model.addVars(U_c, len(Ac), K, T, vtype=GRB.BINARY, name="x")
    y = model.addVars(U_p, len(Ap), K, T, vtype=GRB.BINARY, name="y")
    z = model.addVars(U_b, len(Ab), K, T, vtype=GRB.BINARY, name="z")

    SlackCrit = model.addVars(U_c, len(Ac), vtype=GRB.CONTINUOUS, lb=0)
    SlackPerf = model.addVars(U_p, len(Ap), vtype=GRB.CONTINUOUS, lb=0)
    SlackBus  = model.addVars(U_b, len(Ab), vtype=GRB.CONTINUOUS, lb=0)

    # 2)  PRB-capacity constraints 

    for t_ in range(T):
        for k_ in range(K):
            model.addConstr(quicksum(x[i, a, k_, t_] for i in range(U_c) for a in range(len(Ac))) <= 1)
            model.addConstr(quicksum(y[i, a, k_, t_] for i in range(U_p) for a in range(len(Ap))) <= 1)
            model.addConstr(quicksum(z[i, a, k_, t_] for i in range(U_b) for a in range(len(Ab))) <= 1)

            model.addConstr(
                quicksum(x[i, a, k_, t_] for i in range(U_c) for a in range(len(Ac))) +
                quicksum(y[i, a, k_, t_] for i in range(U_p) for a in range(len(Ap))) +
                quicksum(z[i, a, k_, t_] for i in range(U_b) for a in range(len(Ab))) <= 1
            )

    # 3)  SLA constraints for each Slice

    for i_loc in range(U_c):
        i_glob = crit_users[i_loc]
        for a_idx, a in enumerate(Ac):
            model.addConstr(
                quicksum(
                    x[i_loc, a_idx, k_, t_] * gamma.get((i_glob, a, 1, k_), 0)
                    for k_ in range(K) for t_ in range(T)
                ) >= SLA_critic[a]
            )

    for i_loc in range(U_p):
        i_glob = perf_users[i_loc]
        for a_idx, a in enumerate(Ap):
            model.addConstr(
                quicksum(
                    y[i_loc, a_idx, k_, t_] * gamma.get((i_glob, a, 2, k_), 0)
                    for k_ in range(K) for t_ in range(T)
                )+ SlackPerf[i_loc, a_idx] >= SLA_perf[a]
            )

    for i_loc in range(U_b):
        i_glob = busi_users[i_loc]
        for a_idx, a in enumerate(Ab):
            model.addConstr(
                quicksum(
                    z[i_loc, a_idx, k_, t_] * gamma.get((i_glob, a, 3, k_), 0)
                    for k_ in range(K) for t_ in range(T)
                ) + SlackBus[i_loc, a_idx] >= SLA_busi[a]
            )

    # 4)  Objective 

    alpha_c, alpha_p, alpha_b = 2000, 2000, 1000
    model.setObjective(
        wp * quicksum(y[i, a, k_, t] for i in range(U_p) for a in range(len(Ap)) for k_ in range(K) for t in range(T))
      + wb * quicksum(z[i, a, k_, t] for i in range(U_b) for a in range(len(Ab)) for k_ in range(K) for t in range(T))
      + wc * quicksum(x[i, a, k_, t] for i in range(U_c) for a in range(len(Ac)) for k_ in range(K) for t in range(T))
      + alpha_b * quicksum(SlackBus[i, a] / SLA_busi[Ab[a]] for i in range(U_b) for a in range(len(Ab)))
      + alpha_p * quicksum(SlackPerf[i, a] / SLA_perf[Ap[a]] for i in range(U_p) for a in range(len(Ap))),
      GRB.MINIMIZE
    )

 
    # 5)  Solve

    try:
        model.optimize()
    except Exception as e:
        print(f"Gurobi optimization failed: {e}")
        return (None,)*7

    if model.SolCount == 0:          # no feasible solution found at all
        print("No incumbent solution.")
        return (None,)*7

    # ------------------------------------------------------------
    # 6)  Extract the solution 
    # ------------------------------------------------------------
    prb_assignments, total_throughput = [], 0.0

    for t_ in range(T):
        for k_ in range(K):

            # --- critical slice
            for i_loc in range(U_c):
                i_glob = crit_users[i_loc]
                for a_idx, a in enumerate(Ac):
                    if x[i_loc, a_idx, k_, t_].X > 0.5:
                        thr = gamma.get((i_glob, a, 1, k_), 0)
                        prb_assignments.append((t_, k_, i_glob, a, 1, thr))
                        total_throughput += thr

            # --- performance slice
            for i_loc in range(U_p):
                i_glob = perf_users[i_loc]
                for a_idx, a in enumerate(Ap):
                    if y[i_loc, a_idx, k_, t_].X > 0.5:
                        thr = gamma.get((i_glob, a, 2, k_), 0)
                        prb_assignments.append((t_, k_, i_glob, a, 2, thr))
                        total_throughput += thr

            # --- business slice
            for i_loc in range(U_b):
                i_glob = busi_users[i_loc]
                for a_idx, a in enumerate(Ab):
                    if z[i_loc, a_idx, k_, t_].X > 0.5:
                        thr = gamma.get((i_glob, a, 3, k_), 0)
                        prb_assignments.append((t_, k_, i_glob, a, 3, thr))
                        total_throughput += thr

    # ------------------------------------------------------------
    # 7)  Metrics & DataFrames 
    # ------------------------------------------------------------
    allocation_df = pd.DataFrame(prb_assignments,
                                 columns=['Slot', 'PRB', 'User', 'App', 'Slice', 'Throughput'])
    allocation_df['App_Key'] = allocation_df.apply(
        lambda r: (r['User'], r['App'], r['Slice']), axis=1)

    app_throughput_df = (allocation_df.groupby('App_Key')['Throughput']
                         .sum().reset_index())
    app_throughput_df[['User', 'App', 'Slice']] = pd.DataFrame(
        app_throughput_df['App_Key'].tolist(), index=app_throughput_df.index)
    app_throughput_df.drop(columns=['App_Key'], inplace=True)

    app_episode_thr = (app_throughput_df.groupby('App')['Throughput']
                       .mean().reset_index()
                       .rename(columns={'Throughput': 'Average_Throughput'}))


    violation_counts_per_slice = {1: 0, 2: 0, 3: 0}
    violation_gap_per_slice    = {1: 0, 2: 0, 3: 0}
    for _, row in app_throughput_df.iterrows():
        i, a, s, thr = row['User'], row['App'], row['Slice'], row['Throughput']
        sla = SLA_critic.get(a, 0) if s == 1 else SLA_perf.get(a, 0) if s == 2 else SLA_busi.get(a, 0)
        if thr < sla:
            violation_counts_per_slice[s] += 1
            violation_gap_per_slice[s]   += abs(sla - thr)

    total_violations = sum(violation_counts_per_slice.values())
    violation_gap_per_slice[1] /= ((SLA_critic[1]+SLA_critic[2]) * U_c)
    violation_gap_per_slice[2] /= ((SLA_perf[3]+SLA_perf[4])     * U_p)
    violation_gap_per_slice[3] /= (SLA_busi[5]                   * U_b)

    return (allocation_df, total_throughput, app_throughput_df,
            app_episode_thr, violation_counts_per_slice,
            total_violations, violation_gap_per_slice)


def run_bestcqi_allocation(gamma):
    """
    Assign each PRB in each time slot to (i, a, s) that has the highest achievable Datarate in gamma
  
    """
    prb_assignments = []

    for t in range(T):
        for k_ in range(K):
            best_thr = -float('inf')
            best_keys = []  # will hold all (i,a,s) that achieve best_thr

            #  Scan through all candidates for this PRB k_
            for (i, a, s, prb) in gamma:
                if prb == k_:
                    thr_val = gamma[(i, a, s, prb)]
                    if thr_val > best_thr:
                        best_thr = thr_val
                        best_keys = [(i, a, s)]
                    elif thr_val == best_thr:
                        best_keys.append((i, a, s))

            #  If we found at least one, pick one  
            if best_keys:
                i_sel, a_sel, s_sel = random.choice(best_keys)
                prb_assignments.append((t, k_, i_sel, a_sel, s_sel, best_thr))

    allocation_df = pd.DataFrame(prb_assignments, 
                                 columns=['Slot', 'PRB', 'User', 'App', 'Slice', 'Throughput'])
    #allocation_df.to_csv("bestcqi_allocation_df.csv", index=False)
    allocation_df['App_Key'] = allocation_df.apply(
        lambda row: (row['User'], row['App'], row['Slice']), axis=1
    )
    
    app_throughput_df = (
        allocation_df.groupby('App_Key')['Throughput'].sum().reset_index()
    )

    app_throughput_df[['User', 'App', 'Slice']] = pd.DataFrame(
        app_throughput_df['App_Key'].tolist(), index=app_throughput_df.index
    )
    app_throughput_df.drop(columns=['App_Key'], inplace=True)
    #app_throughput_df.to_csv("bestcqi_allocation_df.csv", index=False)
    
    # ===  Create a DataFrame of all ID combos from APPKEY_LIST ===
    all_combos_df = pd.DataFrame(APPKEY_LIST, columns=['User','App','Slice'])

    # ===  Merge with app_throughput_df, filling missing ID combos as Throughput=0 ===
    merged_df = all_combos_df.merge(
        app_throughput_df,
        on=['User','App','Slice'],
        how='left'
    )
    merged_df['Throughput'] = merged_df['Throughput'].fillna(0.0)

    # === compute the average throughput per App ===
    app_episode_thr = (
        merged_df
        .groupby('App')['Throughput']
        .mean()
        .reset_index()
        .rename(columns={'Throughput': 'Average_Throughput'})
    )
    merged_df.to_csv("CQI_episode_app.csv", index=True)
    violation_counts_per_slice = {1: 0, 2: 0, 3: 0}
    violation_gap_per_slice = {1: 0, 2: 0, 3: 0}

    for (i_, a_, s_) in APPKEY_LIST:
        # Grab how much throughput was allocated to this (user, app, slice)
        row_match = app_throughput_df[
            (app_throughput_df['User'] == i_) &
            (app_throughput_df['App'] == a_) &
            (app_throughput_df['Slice'] == s_)
        ]
        sla_needed = get_sla(a_)
        if len(row_match) > 0:
            allocated_thr = row_match.iloc[0]['Throughput']
            ratio = allocated_thr / sla_needed
            if ratio < 1 :
                #gap_ratio = 1-ratio 
                violation_counts_per_slice[s_] += 1
                violation_gap_per_slice[s_] += (1.0 - ratio)
            

        else:
            allocated_thr = 0.0
            
            violation_counts_per_slice[s_] += 1
            violation_gap_per_slice[s_] += 1.0


  
    for s_ in [1, 2, 3]:
        if violation_counts_per_slice[s_] > 0:
            violation_gap_per_slice[s_] /= violation_counts_per_slice[s_]
        else:
            violation_gap_per_slice[s_] = 0.0

    total_violations = sum(violation_counts_per_slice.values())
    total_throughput = allocation_df['Throughput'].sum() 

    return (allocation_df, total_throughput, app_throughput_df,
            app_episode_thr, violation_counts_per_slice, total_violations, violation_gap_per_slice,)

def run_myheuristic_allocation(gamma):
    """
    Two-phase cascaded scheduler:
      1) Phase Critique : minimal-slack greedy
      2) Phase Performance & Business : weighted Best-CQI
    """
    w_perf= 0.7
    w_busi= 0.3
    # Initialise slack bits for every app
    slack = {key: get_sla(key[1]) for key in APPKEY_LIST}
    prb_assignments = []

    # Phase 1: Critical slice greedy slack reduction
    for t in range(T):
        for k in range(K):
            best_delta = 0.0
            best_choice = None
            # scan critical apps
            for (i, a, s, prb), g in gamma.items():
                if prb != k or s != 1:
                    continue
                need = slack[(i, a, s)]
                if need <= 0:
                    continue
                delta = min(need, g)
                if delta > best_delta:
                    best_delta = delta
                    best_choice = (i, a, s, g)
            if best_choice:
                i, a, s, g = best_choice
                slack[(i, a, s)] -= best_delta
                prb_assignments.append((t, k, i, a, s, g))

          # Phase 2: Weighted Best-CQI for Performance & Business
            weights = {2: w_perf, 3: w_busi}

            # skip PRBs already allocated in Phase 1
            if any(t == rec[0] and k == rec[1] for rec in prb_assignments):
                continue
            best_score = 0.0
            best_choice = None
            for (i, a, s, prb), g in gamma.items():
                if prb != k or s not in (2, 3):
                    continue
                need = slack[(i, a, s)]
                if need <= 0:
                    continue
                score = g * weights[s]
                if score > best_score:
                    best_score = score
                    best_choice = (i, a, s, g)
            if best_choice:
                i, a, s, g = best_choice
                delta = min(slack[(i, a, s)], g)
                slack[(i, a, s)] -= delta
                prb_assignments.append((t, k, i, a, s, g))

    # Build allocation DataFrame
    allocation_df = pd.DataFrame(
        prb_assignments,
        columns=['Slot', 'PRB', 'User', 'App', 'Slice', 'Throughput']
    )
    allocation_df['App_Key'] = allocation_df.apply(
        lambda r: (r['User'], r['App'], r['Slice']), axis=1
    )

    # Per-app throughput
    app_throughput_df = (
        allocation_df.groupby('App_Key')['Throughput']
                     .sum().reset_index()
    )
    app_throughput_df[['User', 'App', 'Slice']] = pd.DataFrame(
        app_throughput_df['App_Key'].tolist(), index=app_throughput_df.index
    )
    app_throughput_df.drop(columns=['App_Key'], inplace=True)

    # Include zero rows for apps with no allocation
    all_combos = pd.DataFrame(APPKEY_LIST, columns=['User','App','Slice'])
    merged = all_combos.merge(
        app_throughput_df, on=['User','App','Slice'], how='left'
    ).fillna(0.0)

    # Average throughput per episode
    app_episode_thr = (
        merged.groupby('App')['Throughput']
              .mean().reset_index()
              .rename(columns={'Throughput':'Average_Throughput'})
    )

    # Violation counts and gap ratios
    violation_counts_per_slice = {1:0, 2:0, 3:0}
    violation_gap_per_slice = {1:0.0,2:0.0,3:0.0}
    for (i, a, s) in APPKEY_LIST:
        sla = get_sla(a)
        allocated = merged.loc[
            (merged.User==i)&(merged.App==a)&(merged.Slice==s),'Throughput'
        ].iloc[0]
        ratio = allocated / sla if sla>0 else 1.0
        if ratio < 1:
            violation_counts_per_slice[s] += 1
            violation_gap_per_slice[s]   += (1 - ratio)
    for s in violation_gap_per_slice:
        if violation_counts_per_slice[s] > 0:
            violation_gap_per_slice[s] /= violation_counts_per_slice[s]

    total_throughput = allocation_df['Throughput'].sum()
    total_violations = sum(violation_counts_per_slice.values())

    return (
        allocation_df,
        total_throughput,
        app_throughput_df,
        app_episode_thr,
        violation_counts_per_slice,
        total_violations,
        violation_gap_per_slice
    )



def run_nvs_allocation(gamma):
    """
    NVS- static reservation and dynamic reuse of unused slots.
    
    gamma: dict mapping (i, app, slice, prb) -> achievable throughput
    APPKEY_LIST: list of all (user, app, slice) combos
    get_sla: function mapping app -> SLA throughput requirement
    K: total number of PRBs per slot
    """
    prb_assignments = []
    # 1) fixed reservation per slice as SLA (50%,30%,20%)
    slot_reservation = {1: 5, 2: 3, 3: 2}
    current_slot = 0

    # track cumulative allocated throughput per (i, app, slice)
    alloc_thr = defaultdict(float)
    
    # extract per-slice list of (user, app)
    slice_apps = {
        s: sorted({(i, a) for (i, a, s_val, k) in gamma if s_val == s})
        for s in slot_reservation
    }
    
    leftover_slots = []

    # First pass: allocate each slice's reserved slots
    for s, rsv_slots in slot_reservation.items():
        apps = slice_apps[s]
        if not apps:
            # no apps in this slice — skip and mark slots as leftover
            leftover_slots.extend(range(current_slot, current_slot + rsv_slots))
            current_slot += rsv_slots
            continue

        app_idx = 0
        for t in range(current_slot, current_slot + rsv_slots):
            # if all apps have met their SLA, free remaining slots
            if all(alloc_thr[(i, a, s)] >= get_sla(a) for (i, a) in apps):
                leftover_slots.extend(range(t, current_slot + rsv_slots))
                break

            # otherwise assign this slot in round-robin among apps
            for k in range(K):
                attempts = 0
                assigned = False
                while not assigned and attempts < len(apps):
                    i_app, a_app = apps[app_idx]
                    app_idx = (app_idx + 1) % len(apps)
                    key = (i_app, a_app, s, k)
                    if key in gamma:
                        thr = gamma[key]
                        prb_assignments.append((t, k, i_app, a_app, s, thr))
                        alloc_thr[(i_app, a_app, s)] += thr
                        assigned = True
                    attempts += 1
        current_slot += rsv_slots

    # Second pass: reuse leftover slots for slices still under SLA
    needy_slices = [
        s for s, apps in slice_apps.items()
        if any(alloc_thr[(i, a, s)] < get_sla(a) for (i, a) in apps)
    ]
    needy_rr = {
        s: {'apps': slice_apps[s], 'idx': 0}
        for s in needy_slices
    }

    for t in leftover_slots:
        for k in range(K):
            for s in needy_slices:
                apps = needy_rr[s]['apps']
                if not apps:
                    continue
                idx = needy_rr[s]['idx']
                i_app, a_app = apps[idx]
                needy_rr[s]['idx'] = (idx + 1) % len(apps)
                key = (i_app, a_app, s, k)
                if key in gamma:
                    thr = gamma[key]
                    prb_assignments.append((t, k, i_app, a_app, s, thr))
                    alloc_thr[(i_app, a_app, s)] += thr
                    break
            else:
                # slot remains unused
                continue
            break

    # Build allocation DataFrame
    allocation_df = pd.DataFrame(
        prb_assignments,
        columns=['Slot', 'PRB', 'User', 'App', 'Slice', 'Throughput']
    )
    allocation_df['App_Key'] = allocation_df.apply(
        lambda row: (row['User'], row['App'], row['Slice']), axis=1
    )

    # Total throughput per (user, app, slice)
    app_throughput_df = (
        allocation_df.groupby('App_Key')['Throughput']
        .sum().reset_index()
    )
    app_throughput_df[['User', 'App', 'Slice']] = pd.DataFrame(
        app_throughput_df['App_Key'].tolist(),
        index=app_throughput_df.index
    )
    app_throughput_df.drop(columns=['App_Key'], inplace=True)

    # DataFrame of all combos for zero-fill
    all_combos_df = pd.DataFrame(APPKEY_LIST, columns=['User', 'App', 'Slice'])
    merged_df = all_combos_df.merge(
        app_throughput_df, on=['User', 'App', 'Slice'], how='left'
    ).fillna({'Throughput': 0.0})

    # Average throughput per App
    app_episode_thr = (
        merged_df.groupby('App')['Throughput']
        .mean().reset_index()
        .rename(columns={'Throughput': 'Average_Throughput'})
    )

    # SLA violation metrics
    violation_counts_per_slice = {s: 0 for s in slot_reservation}
    violation_gap_per_slice = {s: 0.0 for s in slot_reservation}

    for (i_, a_, s_) in APPKEY_LIST:
        sla_needed = get_sla(a_)
        allocated = app_throughput_df.loc[
            (app_throughput_df['User']==i_) &
            (app_throughput_df['App']==a_) &
            (app_throughput_df['Slice']==s_),
            'Throughput'
        ]
        allocated_thr = float(allocated.iloc[0]) if not allocated.empty else 0.0
        if allocated_thr < sla_needed:
            violation_counts_per_slice[s_] += 1
            violation_gap_per_slice[s_] += (1.0 - allocated_thr/sla_needed)

    for s in violation_gap_per_slice:
        if violation_counts_per_slice[s]:
            violation_gap_per_slice[s] /= violation_counts_per_slice[s]

    total_violations = sum(violation_counts_per_slice.values())
    total_throughput = allocation_df['Throughput'].sum()

    return (
        allocation_df, total_throughput, app_throughput_df,
        app_episode_thr, violation_counts_per_slice,
        total_violations, violation_gap_per_slice
    )

def run_simulation(num_simulations=3, alpha=0.8, lambda_weight=0.7):

    simulation_results = []

    for sim in range(1, num_simulations + 1):
        print(f"\n=== Running simulation {sim}/{num_simulations} ===")

        
        gamma = generate_gamma(time_idx=sim+1)

        # ── MY-HSRS
        t0 = time.time()
        (alloc_df_my, total_thr_my, app_thr_df_my,
         app_episode_thr_my, viol_cnt_my,
         tot_viol_my,  viol_gap_my) = run_myheuristic_allocation(gamma)
        time_taken_my = time.time() - t0

        avg_thr_per_app_my = {
            f"Proposed_HSRS_App_{int(app)}_Throughput": avg_thr
            for app, avg_thr in app_episode_thr_my[['App', 'Average_Throughput']]
                                                   .itertuples(index=False)
        }

        # ──  Optimal ILP 
        t0 = time.time()
        (alloc_df_opt, total_thr_opt, app_thr_df_opt,
         app_episode_thr_opt, viol_cnt_opt,
         tot_viol_opt,  viol_gap_opt) = run_allocation_solver(gamma, alpha, lambda_weight)
        time_taken_optimal = time.time() - t0
        avg_thr_per_app_opt = {
            f"Optimal_ILP_App_{int(app)}_Throughput": avg_thr
            for app, avg_thr in app_episode_thr_opt[['App', 'Average_Throughput']]
                                                   .itertuples(index=False)
        } if alloc_df_opt is not None else {}

        # ──  Best-CQI  
        t0 = time.time()
        (alloc_df_cqi, total_thr_cqi, app_thr_df_cqi,
         app_episode_thr_cqi, viol_cnt_cqi,
         tot_viol_cqi,  viol_gap_cqi) = run_bestcqi_allocation(gamma)
        time_taken_bestcqi = time.time() - t0
        avg_thr_per_app_cqi = {
            f"BestCQI_App_{int(app)}_Throughput": avg_thr
            for app, avg_thr in app_episode_thr_cqi[['App', 'Average_Throughput']]
                                                   .itertuples(index=False)
        }

        # ──  NVS  
        t0 = time.time()
        (alloc_df_nvs, total_thr_nvs, app_thr_df_nvs,
         app_episode_thr_nvs, viol_cnt_nvs,
         tot_viol_nvs,  viol_gap_nvs) = run_nvs_allocation(gamma)
        time_taken_nvs = time.time() - t0
        avg_thr_per_app_nvs = {
            f"NVS_App_{int(app)}_Throughput": avg_thr
            for app, avg_thr in app_episode_thr_nvs[['App', 'Average_Throughput']]
                                                   .itertuples(index=False)
        }

        # ──  prepare metrics
        total_prbs   = K * T
        usage_my     = len(alloc_df_my)  / total_prbs * 100
        usage_opt    = len(alloc_df_opt) / total_prbs * 100 if alloc_df_opt is not None else 0
        usage_cqi    = len(alloc_df_cqi) / total_prbs * 100
        usage_nvs    = len(alloc_df_nvs) / total_prbs * 100

        num_apps_slice = {
            s: len({(i, a) for (i, a, s_val, _) in gamma if s_val == s})
            for s in [1, 2, 3]
        }

        def make_rates(viol_cnt, prefix):
            return {f"{prefix}_Violation_Rate_S{s}":
                    (viol_cnt.get(s, 0) / num_apps_slice[s] * 100
                     if num_apps_slice[s] else 0)
                    for s in [1, 2, 3]}

        violation_rates = {
            **make_rates(viol_cnt_opt, "Optimal_ILP"),
            **make_rates(viol_cnt_cqi, "BestCQI"),
            **make_rates(viol_cnt_nvs, "NVS"),
            **make_rates(viol_cnt_my,  "Proposed_HSRS"),
        }

        violation_gap_rates = {
            **{f"Optimal_ILP_Violation_gap_S{s}": viol_gap_opt.get(s, 0) for s in [1, 2, 3]},
            **{f"BestCQI_Violation_gap_S{s}":     viol_gap_cqi.get(s, 0) for s in [1, 2, 3]},
            **{f"NVS_Violation_gap_S{s}":         viol_gap_nvs.get(s, 0) for s in [1, 2, 3]},
            **{f"Proposed_HSRS_Violation_gap_S{s}":         viol_gap_my.get(s, 0)  for s in [1, 2, 3]},
        }

        # ──  collect everything  
        simulation_results.append({
            'Simulation': sim,

            # --- Proposed_HSRS ---
            'Proposed_HSRS_Total_Throughput':  total_thr_my * 0.001,
            'Proposed_HSRS_PRB_Usage (%)':    usage_my,
            'Proposed_HSRS_Time_Taken':       time_taken_my,
            'Proposed_HSRS_Violations_S1':    viol_cnt_my.get(1, 0),
            'Proposed_HSRS_Violations_S2':    viol_cnt_my.get(2, 0),
            'Proposed_HSRS_Violations_S3':    viol_cnt_my.get(3, 0),
            'Proposed_HSRS_Total_Violations': tot_viol_my,

            # --- Optimal ILP ---
            'Optimal_ILP_Total_Throughput': total_thr_opt * 0.001
                                             if alloc_df_opt is not None else 0,
            'Optimal_ILP_PRB_Usage (%)':    usage_opt,
            'Optimal_ILP_Time_Taken':       time_taken_optimal,
            'Optimal_ILP_Violations_S1':    viol_cnt_opt.get(1, 0),
            'Optimal_ILP_Violations_S2':    viol_cnt_opt.get(2, 0),
            'Optimal_ILP_Violations_S3':    viol_cnt_opt.get(3, 0),
            'Optimal_ILP_Total_Violations': tot_viol_opt,

            # --- Best-CQI ---
            'BestCQI_Total_Throughput':      total_thr_cqi * 0.001,
            'BestCQI_PRB_Usage (%)':         usage_cqi,
            'BestCQI_Time_Taken':            time_taken_bestcqi,
            'BestCQI_Violations_S1':         viol_cnt_cqi.get(1, 0),
            'BestCQI_Violations_S2':         viol_cnt_cqi.get(2, 0),
            'BestCQI_Violations_S3':         viol_cnt_cqi.get(3, 0),
            'BestCQI_Total_Violations':      tot_viol_cqi,

            # --- NVS ---
            'NVS_Total_Throughput':          total_thr_nvs * 0.001,
            'NVS_PRB_Usage (%)':             usage_nvs,
            'NVS_Time_Taken':                time_taken_nvs,
            'NVS_Violations_S1':             viol_cnt_nvs.get(1, 0),
            'NVS_Violations_S2':             viol_cnt_nvs.get(2, 0),
            'NVS_Violations_S3':             viol_cnt_nvs.get(3, 0),
            'NVS_Total_Violations':          tot_viol_nvs,

            # --- shared stats ---
            'Min_required_datarate_KB':      min_required_datarate_KB,
            **violation_rates,
            **violation_gap_rates,

            # --- per-app throughput ---
            **avg_thr_per_app_my,
            **avg_thr_per_app_opt,
            **avg_thr_per_app_cqi,
            **avg_thr_per_app_nvs,
        })

    results_df = pd.DataFrame(simulation_results)
    return results_df


def plot_all_results(results_df):

    sns.set(style="whitegrid")  
    palette = {
        'Optimal ILP': '#81D4FA',
        'BestCQI':     '#A5D6A7',
        'NVS':         '#8f9394',
        'Proposed_HSRS':        'orangered'
    }

    # --- 1) Total throughput ---------------------------------
    min_datarate = results_df['Min_required_datarate_KB'].iloc[0]
    plt.figure(figsize=(10, 6))
    for lbl, col, marker in [
        ('Optimal ILP', 'Optimal_ILP_Total_Throughput', 'o'),
        ('BestCQI',     'BestCQI_Total_Throughput',     's'),
        ('NVS',         'NVS_Total_Throughput',         '^'),
        ('Proposed_HSRS',        'Proposed_HSRS_Total_Throughput',        'v')
    ]:
        plt.plot(results_df['Simulation'], results_df[col],
                 marker=marker, label=lbl, color=palette[lbl]) 
    plt.axhline(y=min_datarate, color='r', linestyle='--')   
    plt.text(results_df['Simulation'].min(), min_datarate,
             f'Min total: {min_datarate} KB',
             color='r', fontsize=16, ha='left')               
    plt.xlabel('Allocation Episodes', fontsize=22)
    plt.ylabel('Througput (Kbit/frame)', fontsize=22)
    plt.title('Throughput per Episodes', fontsize=26)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=18)
    plt.legend(fontsize=20)
    plt.tight_layout()
    plt.show()

    # --- 2) PRB-usage ----------------------------------------
    plt.figure(figsize=(10, 6))
    for lbl, col, marker in [
        ('Optimal ILP', 'Optimal_ILP_PRB_Usage (%)', 'o'),
        ('BestCQI',     'BestCQI_PRB_Usage (%)',     's'),
        ('NVS',         'NVS_PRB_Usage (%)',         '^'),
        ('Proposed_HSRS',        'Proposed_HSRS_PRB_Usage (%)',        'v')
    ]:
        plt.plot(results_df['Simulation'], results_df[col],
                 marker=marker, label=lbl, color=palette[lbl])
    plt.xlabel('Allocation Episodes', fontsize=18)
    plt.ylabel('PRB Usage (%)', fontsize=18)
    plt.title('PRB Usage Rate', fontsize=22)
    plt.legend(fontsize=14)
    plt.tight_layout()
    plt.show()

    # --- helper maps -----------------------------------------
    slice_mapping = {1: 'Critical Slice', 2: 'Performance Slice', 3: 'Business Slice'}
    slice_nums = [1, 2, 3]

    # --- 3) Violation Counts per Slice ----------------------
    viol_data = []
    for _, row in results_df.iterrows():
        for method, pref in [
            ('Optimal ILP', 'Optimal_ILP'),
            ('BestCQI',     'BestCQI'),
            ('NVS',         'NVS'),
            ('Proposed_HSRS',        'Proposed_HSRS')
        ]:
            for s in slice_nums:
                viol_data.append({
                    'Method':          method,
                    'Slice':           slice_mapping[s],
                    'Violation_Count': row.get(f'{pref}_Violations_S{s}', 0)
                })
    viol_df = pd.DataFrame(viol_data)
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(data=viol_df, x='Slice', y='Violation_Count', hue='Method',
                     palette=palette, errorbar=None)  
    for x in [0.5, 1.5]:                                 
        ax.axvline(x=x, color='black', linestyle='--', linewidth=1)
    plt.title('Average Violation Occurrence per Slice', fontsize=22)
    plt.xlabel('Slice', fontsize=18)
    plt.ylabel('Violations per Episode', fontsize=18)
    plt.legend(fontsize=14)
    plt.tight_layout()
    plt.show()

    # --- 4) Violation Rates per Slice -----------------------
    rate_data = []
    for _, row in results_df.iterrows():
        for method, pref in [
            ('Optimal ILP', 'Optimal_ILP'),
            ('BestCQI',     'BestCQI'),
            ('NVS',         'NVS'),
            ('Proposed_HSRS',        'Proposed_HSRS')
        ]:
            for s in slice_nums:
                rate_data.append({
                    'Method':              method,
                    'Slice':               slice_mapping[s],
                    'Violation_Rate (%)':  row.get(f'{pref}_Violation_Rate_S{s}', 0)
                })
    rate_df = pd.DataFrame(rate_data)
    rate_df.to_csv("violation_rate_df.csv",index=True)
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(data=rate_df, x='Slice', y='Violation_Rate (%)', hue='Method',
                     palette=palette, errorbar=None)
    for x in [0.5, 1.5]:
        ax.axvline(x=x, color='black', linestyle='--', linewidth=1)
    #plt.title('Violation Rate per Slice', fontsize=22)
    plt.xlabel('', fontsize=0)
    plt.ylabel('Violation Rate (%)', fontsize=22)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.legend(fontsize=14)
    plt.tight_layout()
    plt.show()

    # --- 5) Violation Gap boxplot ---------------------------
    gap_data = []
    for _, row in results_df.iterrows():
        for method, pref in [
            ('Optimal ILP', 'Optimal_ILP'),
            ('BestCQI',     'BestCQI'),
            ('NVS',         'NVS'),
            ('Proposed_HSRS',        'Proposed_HSRS')
        ]:
            for s in slice_nums:
                gap_data.append({
                    'Method':        method,
                    'Slice':         slice_mapping[s],
                    'Violation_gap': row.get(f'{pref}_Violation_gap_S{s}', 0)*100 #turning the gap in percentage
                })
    gap_df = pd.DataFrame(gap_data)
    gap_df.to_csv("gap_df.csv", index=True)

    plt.figure(figsize=(10, 6))
    ax = sns.boxplot(data=gap_df, x='Slice', y='Violation_gap', hue='Method',
                     palette=palette, showmeans=True,
                     meanprops={"marker": "o", "markerfacecolor": "white",
                                "markeredgecolor": "black"})
    for x in [0.5, 1.5]:
        ax.axvline(x=x, color='black', linestyle='--', linewidth=1)
    plt.ylabel('Violation Gap (%)', fontsize=22)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.legend(fontsize=14)
    plt.tight_layout()
    plt.show()

    # --- 6) Per-Application Average Throughput -------------
    cols_opt = [c for c in results_df.columns if c.startswith("Optimal_ILP_App_")]
    cols_cqi = [c for c in results_df.columns if c.startswith("BestCQI_App_")]
    cols_nvs = [c for c in results_df.columns if c.startswith("NVS_App_")]
    cols_hgsr = [c for c in results_df.columns if c.startswith("Proposed_HSRS_App_")]

    avg_opt  = results_df[cols_opt].mean().to_dict()
    avg_cqi  = results_df[cols_cqi].mean().to_dict()
    avg_nvs  = results_df[cols_nvs].mean().to_dict()
    avg_hgsr = results_df[cols_hgsr].mean().to_dict()

    achieved = {
        'Application': app_labels,
        'SLA':         sla_values,
        'Optimal ILP': [avg_opt .get(f"Optimal_ILP_App_{i+1}_Throughput", 0)
                        for i in range(len(app_labels))],
        'BestCQI':     [avg_cqi .get(f"BestCQI_App_{i+1}_Throughput", 0)
                        for i in range(len(app_labels))],
        'NVS':         [avg_nvs .get(f"NVS_App_{i+1}_Throughput", 0)
                        for i in range(len(app_labels))],
        'Proposed_HSRS':[avg_hgsr.get(f"Proposed_HSRS_App_{i+1}_Throughput", 0)
                        for i in range(len(app_labels))]
    }
    bar_df = pd.DataFrame(achieved).melt(
        id_vars=['Application','SLA'],
        var_name='Method', value_name='Throughput'
    )
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(data=bar_df, x='Application', y='Throughput', hue='Method',
                     palette=palette)

    
    for x in [1.5, 3.5]:
        ax.axvline(x=x, color='black', linestyle='--', linewidth=1)

    y_max = bar_df['Throughput'].max()

 
    ax.text(0.5, y_max*1.05, 'Critical slice',     ha='center', va='bottom', fontsize=20)
    ax.text(2.5, y_max*1.05, 'Performance slice',  ha='center', va='bottom', fontsize=20)
    ax.text(4.0, y_max*1.05, 'Business slice',     ha='center', va='bottom', fontsize=20)

    # Plot the SLA lines for each application
    bar_width     = 0.25
    app_positions = np.arange(len(app_labels))
    for i, sla in enumerate(sla_values):
        x_start = app_positions[i] - (1.5 * bar_width)
        x_end   = app_positions[i] + (1.5 * bar_width)
        plt.plot([x_start, x_end], [sla, sla],
                 color='red', linestyle='--', linewidth=2)  
        plt.text(
            i,
            sla + bar_df['Throughput'].max() * 0.01,
            f"SLA: {sla}",
            color='red', ha='right', fontsize=11
        )  

    #plt.title('SLA vs App Data rate per frame', fontsize=22)
    plt.ylabel('Average throughput (Bits/frame)', fontsize=20)
    plt.xlabel('Applications', fontsize=16)
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=14)
    plt.legend(fontsize=18)
    plt.tight_layout()
    plt.show()

# ------------------------------------------------------------------
def print_final_results(results_df):

    summary_cols = [
        'Simulation',
        'Proposed_HSRS_Total_Throughput',
        'Optimal_ILP_Total_Throughput',
        'BestCQI_Total_Throughput',
        'NVS_Total_Throughput',

        'Proposed_HSRS_PRB_Usage (%)',
        'Optimal_ILP_PRB_Usage (%)',
        'BestCQI_PRB_Usage (%)',
        'NVS_PRB_Usage (%)',

        'Proposed_HSRS_Time_Taken',
        'Optimal_ILP_Time_Taken',
        'BestCQI_Time_Taken',
        'NVS_Time_Taken',
    ]

    app_cols_my  = [c for c in results_df.columns if c.startswith("Proposed_HSRS_App_")]
    app_cols_opt = [c for c in results_df.columns if c.startswith("Optimal_ILP_App_")]
    app_cols_cqi = [c for c in results_df.columns if c.startswith("BestCQI_App_")]
    app_cols_nvs = [c for c in results_df.columns if c.startswith("NVS_App_")]

    all_cols = summary_cols + app_cols_my + app_cols_opt + app_cols_cqi + app_cols_nvs
    print("\n=== Final Results Overview ===")
    print(results_df[all_cols].to_string(index=False))

results_df = run_simulation(num_simulations=num_simulations, alpha=0.8, lambda_weight=0.7)
print_final_results(results_df)
plot_all_results(results_df)
# Out:
# the minimumrequire 137.9
#
# === Running simulation 1/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 2/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 3/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 4/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 5/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 6/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 7/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 8/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 9/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 10/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 11/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 12/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 13/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 14/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 15/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 16/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 17/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 18/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 19/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 20/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 21/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 22/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 23/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 24/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 25/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 26/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 27/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 28/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 29/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 30/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 31/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 32/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 33/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 34/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 35/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 36/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 37/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 38/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 39/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 40/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 41/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 42/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 43/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 44/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 45/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 46/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 47/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 48/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 49/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 50/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 51/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 52/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 53/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 54/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 55/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 56/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 57/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 58/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 59/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 60/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 61/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 62/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 63/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 64/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 65/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 66/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 67/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 68/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 69/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 70/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 71/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 72/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 73/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 74/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 75/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 76/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 77/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 78/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 79/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 80/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 81/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 82/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 83/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 84/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 85/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 86/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 87/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 88/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 89/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 90/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 91/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 92/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 93/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 94/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 95/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 96/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 97/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 98/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 99/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 100/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 101/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 102/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 103/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 104/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 105/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 106/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 107/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 108/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 109/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 110/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 111/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 112/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 113/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 114/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 115/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 116/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 117/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 118/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 119/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 120/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 121/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 122/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 123/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 124/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 125/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 126/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 127/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 128/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 129/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 130/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 131/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 132/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 133/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 134/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 135/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 136/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 137/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 138/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 139/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 140/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 141/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 142/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 143/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 144/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 145/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 146/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 147/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 148/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 149/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 150/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 151/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 152/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 153/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 154/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 155/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 156/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 157/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 158/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 159/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 160/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 161/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 162/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 163/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 164/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 165/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 166/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 167/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 168/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 169/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 170/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 171/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 172/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 173/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 174/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 175/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 176/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 177/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 178/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 179/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 180/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 181/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 182/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 183/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 184/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 185/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 186/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 187/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 188/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 189/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 190/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 191/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 192/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 193/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 194/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 195/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 196/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 197/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 198/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 199/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 200/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 201/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 202/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 203/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 204/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 205/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 206/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 207/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 208/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 209/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 210/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 211/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 212/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 213/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 214/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 215/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 216/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 217/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 218/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 219/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 220/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 221/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 222/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 223/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 224/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 225/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 226/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 227/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 228/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 229/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 230/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 231/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 232/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 233/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 234/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 235/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 236/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 237/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 238/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 239/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 240/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 241/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 242/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 243/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 244/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 245/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 246/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 247/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 248/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 249/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 250/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 251/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 252/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 253/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 254/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 255/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 256/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 257/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 258/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 259/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 260/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 261/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 262/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 263/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 264/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 265/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 266/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 267/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 268/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 269/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 270/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 271/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 272/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 273/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 274/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 275/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 276/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 277/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 278/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 279/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 280/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 281/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 282/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 283/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 284/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 285/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 286/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 287/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 288/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 289/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 290/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 291/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 292/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 293/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 294/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 295/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 296/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 297/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 298/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 299/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 300/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 301/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 302/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 303/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 304/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 305/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 306/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 307/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 308/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 309/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 310/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 311/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 312/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 313/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 314/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 315/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 316/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 317/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 318/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 319/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 320/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 321/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 322/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 323/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 324/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 325/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 326/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 327/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 328/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 329/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 330/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 331/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 332/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 333/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 334/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 335/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 336/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 337/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 338/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 339/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 340/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 341/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 342/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 343/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 344/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 345/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 346/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 347/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 348/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 349/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 350/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 351/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 352/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 353/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 354/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 355/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 356/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 357/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 358/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 359/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 360/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 361/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 362/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 363/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 364/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 365/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 366/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 367/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 368/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 369/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 370/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 371/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 372/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 373/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 374/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 375/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 376/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 377/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 378/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 379/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 380/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 381/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 382/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 383/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 384/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 385/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 386/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 387/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 388/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 389/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 390/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 391/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 392/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 393/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 394/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 395/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 396/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 397/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 398/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 399/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 400/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 401/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 402/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 403/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 404/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 405/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 406/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 407/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 408/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 409/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 410/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 411/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 412/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 413/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 414/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 415/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 416/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 417/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 418/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 419/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 420/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 421/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 422/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 423/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 424/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 425/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 426/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 427/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 428/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 429/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 430/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 431/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 432/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 433/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 434/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 435/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 436/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 437/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 438/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 439/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 440/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 441/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 442/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 443/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 444/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 445/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 446/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 447/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 448/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 449/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 450/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 451/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 452/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 453/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 454/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 455/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 456/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 457/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 458/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 459/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 460/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 461/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 462/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 463/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 464/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 465/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 466/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 467/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 468/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 469/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 470/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 471/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 472/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 473/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 474/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 475/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 476/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 477/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 478/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 479/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 480/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 481/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 482/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 483/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 484/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 485/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 486/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 487/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 488/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 489/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 490/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 491/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 492/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 493/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 494/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 495/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 496/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 497/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 498/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 499/500 ===
# Set parameter LogToConsole to value 0
#
# === Running simulation 500/500 ===
# Set parameter LogToConsole to value 0
#
# === Final Results Overview ===
#  Simulation  Proposed_HSRS_Total_Throughput  Optimal_ILP_Total_Throughput  BestCQI_Total_Throughput  NVS_Total_Throughput  Proposed_HSRS_PRB_Usage (%)  Optimal_ILP_PRB_Usage (%)  BestCQI_PRB_Usage (%)  NVS_PRB_Usage (%)  Proposed_HSRS_Time_Taken  Optimal_ILP_Time_Taken  BestCQI_Time_Taken  NVS_Time_Taken  Proposed_HSRS_App_1_Throughput  Proposed_HSRS_App_2_Throughput  Proposed_HSRS_App_3_Throughput  Proposed_HSRS_App_4_Throughput  Proposed_HSRS_App_5_Throughput  Optimal_ILP_App_1_Throughput  Optimal_ILP_App_2_Throughput  Optimal_ILP_App_3_Throughput  Optimal_ILP_App_4_Throughput  Optimal_ILP_App_5_Throughput  BestCQI_App_1_Throughput  BestCQI_App_2_Throughput  BestCQI_App_3_Throughput  BestCQI_App_4_Throughput  BestCQI_App_5_Throughput  NVS_App_1_Throughput  NVS_App_2_Throughput  NVS_App_3_Throughput  NVS_App_4_Throughput  NVS_App_5_Throughput
#           1                      146.685578                    146.051784                247.478437             90.732029                         97.6                       87.2                  100.0               71.2                  0.049392                6.441833            0.034062        0.023034                      609.760159                     1225.869535                    10206.665452                      565.334438                    20452.949986                    594.004690                   1331.313594                  10399.907456                    384.226501                  20144.801213               3448.519364               2548.905617              21937.256211              20361.521214                  0.000000           2131.879538           2127.411572           3644.959508           3452.676943           7422.025089
#           2                      130.057961                    133.347139                226.980337             88.306063                        100.0                      100.0                  100.0               71.2                  0.045038                4.490781            0.034051        0.021992                      717.885000                     1135.804690                    10262.482154                      583.281564                    16176.751190                    571.758910                   1028.103129                  10054.058467                    391.506939                  17880.034919               3446.638115               4712.343111              14936.297214              13472.082716               8996.137471           2398.640788           2361.627195           3769.686385           3552.514885           5783.362277
#           3                      126.962647                    135.268836                218.399015             87.467402                        100.0                      100.0                  100.0               80.8                  0.045515                2.773340            0.035834        0.023065                      658.484533                     1160.731251                    10183.300327                      447.718689                    15723.064224                    672.735000                   1117.603594                   9996.661506                    376.833188                  18164.832655               9593.528409              11932.110277               9492.787471               5695.672483               3325.720771           3292.940004           3251.411409           2725.536195           2823.003758           5114.648453
#           4                      126.022962                    127.758698                227.420549             80.544778                        100.0                      100.0                  100.0               71.2                  0.046001                0.328516            0.034117        0.022304                      588.972346                     1036.098443                    10283.025386                      616.410375                    15443.839711                    594.333908                   1210.208126                  10460.239130                    476.671125                  15561.723516               9404.886065               8179.157632              10372.535218              14010.722207                  0.000000           2125.812505           2186.059536           3546.024570           3355.773759           5041.138610
#           5                      104.842815                    109.257639                181.342153             99.459524                        100.0                      100.0                  100.0              100.0                  0.044154               10.100207            0.033582        0.023230                      594.851255                     1145.728285                     9529.866940                      417.581062                    11165.524466                    600.353908                   1102.647660                  10077.084955                    337.778438                  15655.104094               1601.272964               1847.622651               9828.759914               9749.352350              15689.554416           4788.157514           4676.505327           2653.804130           2655.779442           4030.907356
#           6                      125.905855                    128.698664                209.608874             77.115354                        100.0                      100.0                  100.0               71.2                  0.043394               10.098738            0.034399        0.022352                      585.633128                     1094.981565                    10390.990316                      560.311500                    15266.414367                    559.342658                   1047.668127                  10220.379744                    492.530062                  16373.012595               6937.626698               7443.871071              11168.868341              13495.109209                  0.000000           2006.823443           1939.662819           3627.520317           3608.613753           4313.941425
#           7                      103.344400                    115.358532                201.278700             94.664312                        100.0                      100.0                  100.0              100.0                  0.042805                0.514650            0.034428        0.022530                      598.472663                     1048.420638                    10236.464469                      463.690501                     9990.566256                    531.923445                   1238.238761                  10129.346075                    503.817564                  17190.580322               4661.314208               3922.265148              14759.309212              12456.151281               3424.980226           4057.150805           3916.574399           3096.951383           2778.926071           4360.643456
#           8                      117.586403                    126.409277                202.215562             76.795635                        100.0                      100.0                  100.0               71.2                  0.044889               10.101341            0.036595        0.022409                      636.426876                     1265.893128                    10186.855887                      512.621814                    13168.773543                    601.059376                   1168.115158                  10092.774581                    299.175190                  15958.620266              11897.777469              11598.188409               5596.963295               5025.082109               2032.384916           2259.099066           2501.592189           3223.935759           3302.214570           3900.183992
#           9                      120.389653                    126.246173                210.452615             78.684598                        100.0                      100.0                  100.0               80.8                  0.043995                7.558375            0.035523        0.022567                      652.417502                     1310.760938                    10090.178463                      488.692314                    13929.057215                    614.604376                   1095.404846                  10093.395415                    394.046628                  15887.226792              13826.717144              12418.272305                  0.000000                  0.000000              13245.669568           2532.303601           2245.836259           3233.191513           3260.958764           4386.251963
#          10                      110.919441                    117.520371                198.857531             79.904213                        100.0                      100.0                  100.0               80.8                  0.044862               10.406662            0.036079        0.023685                      615.733128                     1175.216881                    10362.545828                      469.390687                    11503.514547                    510.100940                   1037.368285                  10207.850654                    448.170187                  18318.483803               9056.995916               8052.173259               7023.590415               6988.542729               6535.462500           2947.683605           2725.696104           3372.140634           3164.394198           3295.315093
#          11                      114.179835                    122.666907                187.764740             65.302138                        100.0                      100.0                  100.0               71.2                  0.045830                1.142129            0.036572        0.023607                      679.742659                     1192.947659                    10276.422215                      600.382126                    12139.917942                    686.515156                   1083.317813                  10094.862781                    454.942689                  19766.293812               9474.304197              10516.704817               4736.065673               7781.997538               1307.092500           1469.820630           1478.662507           3541.453139           3364.803766           3269.988769
# ...
#         483                      129.360958                    139.434206                249.318299            134.353419                        100.0                      100.0                  100.0              100.0                  0.041175                1.324369            0.032038        0.021202                      560.706564                     1262.083594                    10511.653699                      685.884936                    15609.131058                    670.712657                   1104.293750                  10208.076378                    673.468687                  18594.110436               9489.965598               7325.587479              10330.771485              12157.314731               8996.137471           6032.040002           5674.696566           4646.047876           4567.881938           4510.837749
#         484                      124.484194                    131.993486                252.162750            131.088228                        100.0                      100.0                  100.0              100.0                  0.040813               10.098485            0.032278        0.022058                      670.477500                     1499.873594                    10384.104956                      653.997750                    14067.893490                    690.747970                   1065.822191                  10200.739506                    379.711502                  17137.952435              13158.967471              13291.407471               9146.261239               9545.838738                  0.000000           6315.591408           6025.032347           4166.272691           3946.674382           4119.937519
#         485                      134.865025                    143.865396                266.802637            124.807016                        100.0                      100.0                  100.0               90.4                  0.041900                1.036195            0.033950        0.021492                      715.063127                     1218.438596                    10387.547643                      652.981876                    17015.341874                    741.024375                   1184.246876                  10203.504953                    584.636063                  19593.265758              11533.003123              14921.510623              10700.550000              10914.561000                  0.000000           5078.387346           5252.026723           4018.970824           4129.193258           5520.927907
#         486                      123.456749                    138.073498                250.447049            135.866509                        100.0                      100.0                  100.0              100.0                  0.041805               10.100286            0.032251        0.022001                      670.101251                     1360.661097                    10564.084125                      655.634436                    13793.395609                    672.876094                   1033.464689                   9982.664997                    711.846186                  18590.724233              16815.553076              16482.571827               3867.097492               6264.562485                  0.000000           6371.182347           6071.170004           4385.024439           4257.757875           4499.620798
#         487                      125.682080                    135.064532                240.062550            126.326314                        100.0                      100.0                  100.0               90.4                  0.041222                2.220598            0.032649        0.021274                      681.059531                     1412.442499                    10226.136379                      550.209189                    14809.834952                    685.151251                    981.024845                  10038.594551                    588.981751                  17982.398468              16642.007780              20894.291212               1066.781622               1902.169494                  0.000000           5116.764844           5246.053750           4657.335380           4453.596003           4648.686343
#         488                      122.321227                    138.955898                257.140537            136.642242                        100.0                      100.0                  100.0              100.0                  0.041260                1.100344            0.032277        0.021493                      686.938440                     1117.791721                    10453.015107                      652.417501                    13991.420662                    604.257502                    996.827348                  10147.631796                    425.030814                  19121.518885              12172.816234              17605.113728               7619.062497               8075.528998                  0.000000           5893.344848           5909.382504           4668.227807           4594.068932           4878.598620
#         489                      116.135113                    125.029945                224.482978            126.210899                        100.0                      100.0                  100.0              100.0                  0.040664                0.421167            0.033291        0.021199                      642.587970                     1105.892814                    10244.252848                      532.262064                    12940.413354                    549.889376                   1115.204999                  10135.554205                    458.893314                  15516.785218              11781.045917              11551.345296               8127.846557               8769.879557                  0.000000           6050.335159           6111.946094           3628.649078           3433.883266           4481.137530
#         490                      127.242295                    139.883448                243.900300            113.720434                        100.0                      100.0                  100.0               90.4                  0.041541               10.098349            0.031655        0.021688                      647.102971                     1225.352188                    10255.596791                      586.780688                    15448.919140                    700.248282                   1224.552656                  10050.277169                    579.161626                  18796.862207               6403.398734               6995.239985              13726.502986              18975.190483                  0.000000           4500.984698           4488.709539           4116.099764           4010.561636           4787.240419
#         491                      123.148036                    126.977321                245.740162             94.569215                        100.0                      100.0                  100.0               80.8                  0.041131               10.098017            0.033034        0.022260                      775.404220                     1098.979219                    10442.912823                      687.408749                    14062.531926                    655.803751                    997.250627                  10094.693453                    552.748877                  15955.445688              10931.802643              11180.833109              11223.217664              11389.651847                  0.000000           3354.974216           3323.792499           4049.164885           3855.810009           3742.935016
#         492                      133.182059                    140.674702                257.851650            113.690804                        100.0                      100.0                  100.0               90.4                  0.042098                4.026514            0.032043        0.021047                      670.195315                     1167.174534                    10430.722325                      682.780876                    16647.581075                    682.799688                   1080.401876                  10098.926263                    417.976127                  19377.745151              14369.739985              18261.669977               6206.319000               6206.319000                  0.000000           4788.439690           4536.446255           4203.521445           3884.198070           4325.722762
#         493                      133.984318                    137.715684                260.120437            133.358991                        100.0                      100.0                  100.0              100.0                  0.041959               10.097015            0.032073        0.021765                      773.099686                     1182.553750                    10315.589808                      695.592187                    16798.621902                    544.480783                   1048.843907                  10107.899790                    548.403187                  18718.555135              14327.223745              13637.557496              10377.953225               8088.396733                  0.000000           5853.039071           5751.921880           4381.638190           4349.243063           5018.704704
#         494                      141.335021                    145.314711                264.669300             92.884273                        100.0                       94.0                  100.0               71.2                  0.043343                1.229082            0.031531        0.020758                      758.567031                     1302.436407                    10554.489762                      685.489875                    18192.275463                    682.564533                   1088.820471                  10275.011240                    543.210938                  20148.822511              20687.730000              16764.195000               3995.774988               3995.774988                  0.000000           2488.423441           2252.749848           4562.181754           4261.821379           5079.304482
#         495                      129.487661                    140.956325                261.824850             95.238564                        100.0                      100.0                  100.0               80.8                  0.042655                1.395514            0.032301        0.020728                      637.555627                     1145.446095                    10299.561586                      624.932439                    16041.795069                    718.496407                   1037.415313                  10241.713137                    582.491439                  19074.957970              11724.326234              14435.583728              11128.572000               9844.506000                  0.000000           3287.672501           3275.961720           4051.930328           3892.663701           4033.447053
#         496                      123.676856                    134.316171                255.424837             95.186641                        100.0                      100.0                  100.0               80.8                  0.041339               10.104486            0.034286        0.022968                      741.494688                     1188.291564                    10279.526262                      599.084064                    14426.271609                    727.667500                   1138.156251                  10076.633426                    339.471564                  17760.175837              19881.802467              20025.153709               1598.309995               1598.309995                  0.000000           3301.875940           3194.503596           4105.545948           4150.470194           3732.070798
#         497                      115.348091                    124.417880                254.296087            104.039992                        100.0                      100.0                  100.0               90.4                  0.043418                6.213840            0.035798        0.022336                      742.811564                     1052.089066                    10339.011387                      658.682061                    12397.555109                    679.131251                   1066.057348                  10069.353001                    527.634188                  15240.453063              17954.649977              17768.406230               3596.197490               4395.352487                  0.000000           4143.406103           4201.865944           4108.367820           3948.593253           3420.888525
#         498                      122.454701                    133.971338                251.034000             80.743156                        100.0                      100.0                  100.0               71.2                  0.042828                5.444747            0.032256        0.020183                      644.657346                     1129.737658                    10298.376395                      657.609749                    14257.100177                    607.267501                    975.334066                  10071.836260                    487.281375                  17920.035020              15603.275615              14059.709990               4835.790736               2578.516492               8996.137471           2107.188132           2010.350789           4075.239009           3747.619320           4230.907744
#         499                       99.971977                    113.320010                264.669300            112.450590                        100.0                      100.0                  100.0              100.0                  0.045262               10.103814            0.031219        0.021474                      644.516256                     1167.927045                    10237.931839                      629.278126                     8690.316847                    666.715006                   1004.070169                  10051.010830                    454.209003                  16923.066621              21222.757500              16229.167500               5394.296234               2597.253742                  0.000000           4940.538756           4832.696101           3888.261575           4008.473452           3581.876507
#         500                       99.661006                    112.950062                243.900300            106.267298                        100.0                      100.0                  100.0              100.0                  0.039673                0.987342            0.031718        0.021425                      692.864381                     1317.909698                    10412.041516                      475.429501                     8289.751647                    547.161569                    991.324699                  10229.861246                    368.593316                  16908.957212              14294.489981              13224.434981               6979.061241               6439.292993               2923.744678           4377.433601           4287.603916           3777.023256           3832.557756           4057.291881

# %% [markdown]
# ## Load Result file & compute AVG execution time

# %%
#results_df.to_csv("results.csv", index=True)  #saving the result in csv file 
results_trimed = results_df[['Proposed_HSRS_Time_Taken','BestCQI_Time_Taken','NVS_Time_Taken','Optimal_ILP_Time_Taken']]
meanvalues = results_df[['Proposed_HSRS_Time_Taken','BestCQI_Time_Taken','NVS_Time_Taken','Optimal_ILP_Time_Taken']].mean()

print(meanvalues)
# Out:
# Proposed_HSRS_Time_Taken    0.044451
# BestCQI_Time_Taken          0.034408
# NVS_Time_Taken              0.022703
# Optimal_ILP_Time_Taken      6.632338
# dtype: float64

# %% [markdown]
# ## Display Violation rates for weight tradeoff comaprison

# %%
rate_df = pd.read_csv("violation_rate_df.csv", index_col=0)
gap_df  = pd.read_csv("gap_df.csv",  index_col=0)

# ---  Define the slices we care about ---
target_slices = ["Performance Slice", "Business Slice"]

# --- Filter to Proposed_HSRS + targeted slices ---
mask_rate = (rate_df["Method"] == "Proposed_HSRS") & (rate_df["Slice"].isin(target_slices))
mask_gap  = (gap_df["Method"]  == "Proposed_HSRS") & (gap_df["Slice"].isin(target_slices))

# --- a. Compute mean violation rate for Performance and Business separately ---
perf_rate = rate_df.loc[
    (rate_df["Method"] == "Proposed_HSRS") &
    (rate_df["Slice"]  == "Performance Slice"),
    "Violation_Rate (%)"
].mean()

busi_rate = rate_df.loc[
    (rate_df["Method"] == "Proposed_HSRS") &
    (rate_df["Slice"]  == "Business Slice"),
    "Violation_Rate (%)"
].mean()

# --- b. Compute mean violation gap for Performance and Business separately ---
perf_gap = gap_df.loc[
    (gap_df["Method"] == "Proposed_HSRS") &
    (gap_df["Slice"]  == "Performance Slice"),
    "Violation_gap"
].mean()

busi_gap = gap_df.loc[
    (gap_df["Method"] == "Proposed_HSRS") &
    (gap_df["Slice"]  == "Business Slice"),
    "Violation_gap"
].mean()

# --- 5. Print out all four ---
print(f"Performance Slice – Violation Rate: {perf_rate:.2f}%")
print(f"Business   Slice – Violation Rate: {busi_rate:.2f}%")
print(f"Performance Slice – Violation Gap : {perf_gap:.2f}")
print(f"Business   Slice – Violation Gap : {busi_gap:.2f}")
# Out:
# Performance Slice – Violation Rate: 3.00%
# Business   Slice – Violation Rate: 37.50%
# Performance Slice – Violation Gap : 10.02
# Business   Slice – Violation Gap : 82.96

# %% [markdown]
# ## Priority Weight trade-off on violations

# %%
from matplotlib.patches import Rectangle
from matplotlib import colors
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize


df = pd.read_excel('weight_tradeoff.ods', engine='odf')


mat_rp = df.pivot(index='Wb', columns='Wp', values='Rate_perf')
mat_rb = df.pivot(index='Wb', columns='Wp', values='Rate_busi')
mat_gp = df.pivot(index='Wb', columns='Wp', values='gap_perf')
mat_gb = df.pivot(index='Wb', columns='Wp', values='gap_busi')

# build color‐map and normalisation on given values
cmap = plt.cm.get_cmap('RdYlGn_r')
norm_rp = colors.Normalize(mat_rp.min().min(), mat_rp.max().max())
norm_rb = colors.Normalize(mat_rb.min().min(), mat_rb.max().max())
norm_gp = colors.Normalize(mat_gp.min().min(), mat_gp.max().max())
norm_gb = colors.Normalize(mat_gb.min().min(), mat_gb.max().max())

# sorted weight axes
wp_vals = sorted(df['Wp'].unique())
wb_vals = sorted(df['Wb'].unique())


fig, ax = plt.subplots(figsize=(9,9))

for _, row in df.iterrows():
    wp, wb = row['Wp'], row['Wb']
    i = wp_vals.index(wp)
    j = wb_vals.index(wb)

    # extract data
    v_rp, v_rb = row['Rate_perf'], row['Rate_busi']
    v_gp, v_gb = row['gap_perf'],  row['gap_busi']

    # Top-Left = Rate_busi
    ax.add_patch(Rectangle((i, j+0.5), .5, .5,
                           facecolor=cmap(norm_rb(v_rb)), edgecolor='none'))
    ax.text(i+0.25, j+0.75, f'{v_rb:.1f}',
            ha='center', va='center', color='black', fontsize=10)

    # Top-Right = Rate_perf
    ax.add_patch(Rectangle((i+.5, j+0.5), .5, .5,
                           facecolor=cmap(norm_rp(v_rp)), edgecolor='none'))
    ax.text(i+0.75, j+0.75, f'{v_rp:.1f}',
            ha='center', va='center', color='black', fontsize=10)

    # Bottom-Left = gap_busi
    ax.add_patch(Rectangle((i, j), .5, .5,
                           facecolor=cmap(norm_gb(v_gb)), edgecolor='none'))
    ax.text(i+0.25, j+0.25, f'{v_gb:.1f}',
            ha='center', va='center', color='black', fontsize=10)

    # Bottom-Right = gap_perf
    ax.add_patch(Rectangle((i+.5, j), .5, .5,
                           facecolor=cmap(norm_gp(v_gp)), edgecolor='none'))
    ax.text(i+0.75, j+0.25, f'{v_gp:.1f}',
            ha='center', va='center', color='black', fontsize=10)

# ── set the axes ────────────────────────────────────────────────────────
ax.set_xlim(0, len(wp_vals))
ax.set_ylim(0, len(wb_vals))

ax.set_xticks(np.arange(len(wp_vals)) + 0.5)
ax.set_xticklabels(wp_vals)
ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Performance slice Weight', fontsize=20)

ax.set_yticks(np.arange(len(wb_vals)) + 0.5)
ax.set_yticklabels(wb_vals)
ax.tick_params(axis='y', labelsize=16)
ax.set_ylabel('Business slice Weight', fontsize=20)

ax.set_title('Priority Weight trade-off on violations', fontsize=18)

# set the grey grid intersections
ax.set_axisbelow(True)
ax.grid(which='both', color='lightgrey', linestyle='-', linewidth=0.5)

# ── Add the "Quadrant legend” 
legend_ax = fig.add_axes([0.65, 0.75, 0.19, 0.19])  # [left, bottom, width, height]
legend_ax.axis('off')

# sample mid-points to pull match-colormap colors
mid_rb = 0.5*(norm_rb.vmin + norm_rb.vmax)
mid_rp = 0.5*(norm_rp.vmin + norm_rp.vmax)
mid_gb = 0.5*(norm_gb.vmin + norm_gb.vmax)
mid_gp = 0.5*(norm_gp.vmin + norm_gp.vmax)

c_tl = cmap(norm_rb(mid_rb))
c_tr = cmap(norm_rp(mid_rp))
c_bl = cmap(norm_gb(mid_gb))
c_br = cmap(norm_gp(mid_gp))

tbl = legend_ax.table(
    cellText=[['%', '%'],
              ['%', '%']],
    cellColours=[[c_tl, c_tr],
                 [c_bl, c_br]],      
    rowLabels=['Violation Rate', 'Violation Gap'],
    colLabels=['Busi. slice', 'Perf. slice'],
    cellLoc='center',
    rowLoc='center',
    colLoc='center',
    loc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(12)
tbl.scale(1, 1.5)
legend_ax.text(0.5, 0.8,     
    'Quadrant values legend',
    transform=legend_ax.transAxes, ha='center', va='bottom', fontsize=13)

# draw borders around the four data cells
for (r, c), cell in tbl.get_celld().items():
    if r > 0 and c >= 0:
        cell.set_edgecolor('black')
        cell.set_linewidth(0.8)
    else:
        cell.set_edgecolor('none')
        cell.set_linewidth(0)


# create a color legend for a 0→1 ramp
sm = ScalarMappable(cmap=cmap, norm=Normalize(vmin=0, vmax=1))
sm.set_array([])  

# add the colorbar to the main axes
cbar = fig.colorbar(sm, ax=ax, orientation='vertical', fraction=0.04, pad=0.02) 


cbar.set_ticks([0,1])
cbar.set_ticklabels(['Low','High'])


plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_180432/3678832707.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('RdYlGn_r')
# /tmp/ipykernel_180432/3678832707.py:138: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
